# %% [markdown]
# # Inference Demo
#
# Run this notebook after installing `requirements.txt` and placing trained weights in `checkpoints/best_model`.

# %%
from inference import predict

sample_text = "This is a sample tweet for inference."
predict(sample_text)
